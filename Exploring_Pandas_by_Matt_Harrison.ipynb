# %% [markdown]
# <a href="https://colab.research.google.com/github/Sahilkhurana93/DeepLearningOwl/blob/main/Exploring_Pandas_by_Matt_Harrison.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Chapter 1 - Introduction
# Built upon Cpython and numpy

# %% [markdown]
# # Chapter 2 - Installation
# on Windows
#
# python -m venv pandas-env
#
# pandas-env/Scripts/active
#
# (pandas-env)>pip install pandas

# %% [markdown]
# # Chapter 3 - Data Structure

# %% [markdown]
# Relationship between the data structure in pandas
#
# ![IMG_0443.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# # Chapter 4 - Categorial Data

# %%
## Example of creating dataframe
import pandas as pd
Example1 = pd.Series([145,142,38,13],
                     name='counts',
                     index=['Paul','John','George','Ringo'])

# %%
Example1
# Out:
# Paul      145
# John      142
# George     38
# Ringo      13
# Name: counts, dtype: int64

# %% [markdown]
# ### Categorical Data

# %%
s=pd.Series(['m','l','xs','s','xl'],dtype='category')
s
# Out:
# 0     m
# 1     l
# 2    xs
# 3     s
# 4    xl
# dtype: category
# Categories (5, object): ['l', 'm', 's', 'xl', 'xs']

# %% [markdown]
# # Chapter 5 - Series Deep Drive

# %%
url = 'https://github.com/mattharrison/datasets/raw/master/data/vehicles.csv.zip'
url
# Out:
# 'https://github.com/mattharrison/datasets/raw/master/data/vehicles.csv.zip'

# %%
df=pd.read_csv(url)
df
# Out:
# <ipython-input-12-d11b6562b7f3>:1: DtypeWarning: Columns (68,70,71,72,73,74,76,79) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv(url)
#        barrels08  barrelsA08  charge120  charge240  city08  city08U  cityA08  \
# 0      15.695714         0.0        0.0        0.0      19      0.0        0
# 1      29.964545         0.0        0.0        0.0       9      0.0        0
# 2      12.207778         0.0        0.0        0.0      23      0.0        0
# 3      29.964545         0.0        0.0        0.0      10      0.0        0
# 4      17.347895         0.0        0.0        0.0      17      0.0        0
# ...          ...         ...        ...        ...     ...      ...      ...
# 41139  14.982273         0.0        0.0        0.0      19      0.0        0
# 41140  14.330870         0.0        0.0        0.0      20      0.0        0
# 41141  15.695714         0.0        0.0        0.0      18      0.0        0
# ...

# %% [markdown]
# # Chapter 6 - Operators (& Dunder Methods)

# %%
2+4
# Out:
# 6

# %%
(2).__add__(4)
# Out:
# 6

# %% [markdown]
# ## Index Alignment
#
# * Are unique
#
# * Are comman to both series

# %%
import pandas as pd
s1 = pd.Series([10,20,30], index=[1,2,2])
s1
# Out:
# 1    10
# 2    20
# 2    30
# dtype: int64

# %%
s2=pd.Series([35,44,53], index=[2,2,4], name='s2')
s2
# Out:
# 2    35
# 2    44
# 4    53
# Name: s2, dtype: int64

# %%
s1 + s2
# Out:
# 1     NaN
# 2    55.0
# 2    64.0
# 2    65.0
# 2    74.0
# 4     NaN
# dtype: float64

# %% [markdown]
# ## BroadCasting/Duplicate Index Alignment

# %%
s1.add(s2,fill_value=0)
# Out:
# 1    10.0
# 2    55.0
# 2    64.0
# 2    65.0
# 2    74.0
# 4    53.0
# dtype: float64
