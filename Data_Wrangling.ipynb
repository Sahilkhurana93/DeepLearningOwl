# %% [markdown]
# <a href="https://colab.research.google.com/github/Sahilkhurana93/DeepLearningOwl/blob/main/Data_Wrangling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Wrangling with Pandas

# %%
import pandas as pd

# %% [markdown]
# ## Multifile access

# %%
import os
folder = os.path.join('/content/drive/MyDrive/Colab Notebooks/DataSets/Multi_dataSet/reading_csv/datasets/multi-directory/')
folder
# Out:
# '/content/drive/MyDrive/Colab Notebooks/DataSets/Multi_dataSet/reading_csv/datasets/multi-directory/'

# %%
import glob

# %%
for dir in glob.glob('/content/drive/MyDrive/Colab Notebooks/DataSets/Multi_dataSet/reading_csv/datasets/multi-directory/*'):
  print(dir)
# Out:
# /content/drive/MyDrive/Colab Notebooks/DataSets/Multi_dataSet/reading_csv/datasets/multi-directory/1987
# /content/drive/MyDrive/Colab Notebooks/DataSets/Multi_dataSet/reading_csv/datasets/multi-directory/2007
# /content/drive/MyDrive/Colab Notebooks/DataSets/Multi_dataSet/reading_csv/datasets/multi-directory/2009
# /content/drive/MyDrive/Colab Notebooks/DataSets/Multi_dataSet/reading_csv/datasets/multi-directory/1985
# /content/drive/MyDrive/Colab Notebooks/DataSets/Multi_dataSet/reading_csv/datasets/multi-directory/1997
# /content/drive/MyDrive/Colab Notebooks/DataSets/Multi_dataSet/reading_csv/datasets/multi-directory/1999
# /content/drive/MyDrive/Colab Notebooks/DataSets/Multi_dataSet/reading_csv/datasets/multi-directory/1998
# /content/drive/MyDrive/Colab Notebooks/DataSets/Multi_dataSet/reading_csv/datasets/multi-directory/2002
# /content/drive/MyDrive/Colab Notebooks/DataSets/Multi_dataSet/reading_csv/datasets/multi-directory/2004

# %%
for dir in glob.glob('/content/drive/MyDrive/Colab Notebooks/DataSets/Multi_dataSet/reading_csv/datasets/multi-directory/*'):
  for files in glob.glob(dir + '/*'):
    print(files)
# Out:
# /content/drive/MyDrive/Colab Notebooks/DataSets/Multi_dataSet/reading_csv/datasets/multi-directory/1987/1987.csv
# /content/drive/MyDrive/Colab Notebooks/DataSets/Multi_dataSet/reading_csv/datasets/multi-directory/2007/2007.csv
# /content/drive/MyDrive/Colab Notebooks/DataSets/Multi_dataSet/reading_csv/datasets/multi-directory/2009/2009.csv
# /content/drive/MyDrive/Colab Notebooks/DataSets/Multi_dataSet/reading_csv/datasets/multi-directory/1985/1985.csv
# /content/drive/MyDrive/Colab Notebooks/DataSets/Multi_dataSet/reading_csv/datasets/multi-directory/1997/1997.csv
# /content/drive/MyDrive/Colab Notebooks/DataSets/Multi_dataSet/reading_csv/datasets/multi-directory/1999/1999.csv
# /content/drive/MyDrive/Colab Notebooks/DataSets/Multi_dataSet/reading_csv/datasets/multi-directory/1998/1998.csv
# /content/drive/MyDrive/Colab Notebooks/DataSets/Multi_dataSet/reading_csv/datasets/multi-directory/2002/2002.csv
# ...

# %%
great_list = []
for dir in glob.glob('/content/drive/MyDrive/Colab Notebooks/DataSets/Multi_dataSet/reading_csv/datasets/multi-directory/*'):
  for files in glob.glob(dir + '/*'):
    great_list.append(pd.read_csv(files))

# %%
great_list

# %%
final_data = pd.concat(great_list)
final_data
# Out:
#      Unnamed: 0 Item_Identifier  Item_Weight Item_Fat_Content  \
# 0             4           NCD19         8.93          Low Fat
# 1             6           FDO10        13.65          Regular
# 2            14           FDF32        16.35          Low Fat
# 3            20           FDN22        18.85          Regular
# 4            27           DRJ59        11.65          low fat
# ..          ...             ...          ...              ...
# 925        8503           FDQ44        20.50          Low Fat
# 926        8507           FDN28         5.88          Regular
# 927        8510           FDN58        13.80          Regular
# 928        8513           FDH31        12.00          Regular
# 929        8520           NCJ29        10.60          Low Fat
#
#      Item_Visibility              Item_Type  Item_MRP Outlet_Identifier  \
# 0           0.000000              Household   53.8614            OUT013
# 1           0.012741            Snack Foods   57.6588            OUT013
# ...

# %%
final_data.to_csv('/content/drive/MyDrive/Colab Notebooks/DataSets/merged_csv_big_sales.csv', index=False)

# %%
df=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/DataSets/merged_csv_big_sales.csv')

# %%
df
# Out:
#       Unnamed: 0 Item_Identifier  Item_Weight Item_Fat_Content  \
# 0              4           NCD19         8.93          Low Fat
# 1              6           FDO10        13.65          Regular
# 2             14           FDF32        16.35          Low Fat
# 3             20           FDN22        18.85          Regular
# 4             27           DRJ59        11.65          low fat
# ...          ...             ...          ...              ...
# 8518        8503           FDQ44        20.50          Low Fat
# 8519        8507           FDN28         5.88          Regular
# 8520        8510           FDN58        13.80          Regular
# 8521        8513           FDH31        12.00          Regular
# 8522        8520           NCJ29        10.60          Low Fat
#
#       Item_Visibility              Item_Type  Item_MRP Outlet_Identifier  \
# 0            0.000000              Household   53.8614            OUT013
# ...

# %% [markdown]
# ### Working with excel files

# %%
import os
import pandas as pd

# %%
folder1 = os.path.join('/content/drive/MyDrive/Colab Notebooks/DataSets/Multi_dataSet/reading_excel/datasets/big_mart_sales.xlsx')

# %%
folder1
# Out:
# '/content/drive/MyDrive/Colab Notebooks/DataSets/Multi_dataSet/reading_excel/datasets/big_mart_sales.xlsx'

# %%
df_excel= pd.read_excel('/content/drive/MyDrive/Colab Notebooks/DataSets/Multi_dataSet/reading_excel/datasets/big_mart_sales.xlsx')
df_excel
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
df_excel_1985= pd.read_excel('/content/drive/MyDrive/Colab Notebooks/DataSets/Multi_dataSet/reading_excel/datasets/big_mart_sales_with_multiple_sheets.xlsx',sheet_name='1985')

# %%
df_excel_1985
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDP10          NaN          Low Fat         0.127470
# 1              DRI11          NaN          Low Fat         0.034238
# 2              FDW12          NaN          Regular         0.035400
# 3              FDC37          NaN          Low Fat         0.057557
# 4              FDC14          NaN          Regular         0.072222
# ...              ...          ...              ...              ...
# 1458           DRK37          NaN          Low Fat         0.043792
# 1459           DRG13          NaN          Low Fat         0.037006
# 1460           NCN14          NaN          Low Fat         0.091473
# 1461           FDU44          NaN          Regular         0.102296
# 1462           NCN18          NaN          Low Fat         0.124111
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0               Snack Foods  107.7622            OUT027
# ...

# %%
df_excel_1987= pd.read_excel('/content/drive/MyDrive/Colab Notebooks/DataSets/Multi_dataSet/reading_excel/datasets/big_mart_sales_with_multiple_sheets.xlsx',sheet_name='1987')
df_excel_1987
# Out:
#     Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0             NCD19        8.930          Low Fat         0.000000
# 1             FDO10       13.650          Regular         0.012741
# 2             FDF32       16.350          Low Fat         0.068024
# 3             FDN22       18.850          Regular         0.138190
# 4             DRJ59       11.650          low fat         0.019356
# ..              ...          ...              ...              ...
# 927           FDQ31        5.785          Regular         0.053802
# 928           FDJ32       10.695          Low Fat         0.057744
# 929           DRJ49        6.865          Low Fat         0.000000
# 930           FDR26       20.700          Low Fat         0.042801
# 931           FDF22        6.865          Low Fat         0.056783
#
#                  Item_Type  Item_MRP Outlet_Identifier  \
# 0                Household   53.8614            OUT013
# ...

# %%
df_excel_1997= pd.read_excel('/content/drive/MyDrive/Colab Notebooks/DataSets/Multi_dataSet/reading_excel/datasets/big_mart_sales_with_multiple_sheets.xlsx',sheet_name='1997')
df_excel_1997
# Out:
#     Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0             FDA03       18.500          Regular         0.045464
# 1             FDS46       17.600          Regular         0.047257
# 2             FDP49        9.000          Regular         0.069089
# 3             FDR28       13.850          Regular         0.025896
# 4             DRH01       17.500          Low Fat         0.097904
# ..              ...          ...              ...              ...
# 925           FDC28        7.905          Low Fat         0.054987
# 926           FDB17       13.150          Low Fat         0.036672
# 927           FDT34        9.300          Low Fat         0.174350
# 928           FDF53       20.750              reg         0.083607
# 929           DRG01       14.800          Low Fat         0.044878
#
#         Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 0           Dairy  144.1102            OUT046                       1997
# ...

# %%
final=[df_excel_1985,df_excel_1987,df_excel_1997]
final_data=pd.concat(final)
final_data
# Out:
#     Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0             FDP10          NaN          Low Fat         0.127470
# 1             DRI11          NaN          Low Fat         0.034238
# 2             FDW12          NaN          Regular         0.035400
# 3             FDC37          NaN          Low Fat         0.057557
# 4             FDC14          NaN          Regular         0.072222
# ..              ...          ...              ...              ...
# 925           FDC28        7.905          Low Fat         0.054987
# 926           FDB17       13.150          Low Fat         0.036672
# 927           FDT34        9.300          Low Fat         0.174350
# 928           FDF53       20.750              reg         0.083607
# 929           DRG01       14.800          Low Fat         0.044878
#
#         Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 0     Snack Foods  107.7622            OUT027                       1985
# ...

# %% [markdown]
# ### Managing Json Files

# %%
import os
folder_Json=os.path.join('/content/drive/MyDrive/Colab Notebooks/DataSets/Multi_dataSet/Reading_Json/')
folder_Json
# Out:
# '/content/drive/MyDrive/Colab Notebooks/DataSets/Multi_dataSet/Reading_Json/'

# %%
Json_1=pd.read_json('/content/drive/MyDrive/Colab Notebooks/DataSets/Multi_dataSet/Reading_Json/simple_records.json',lines=True)
Json_1
# Out:
#        name  age grade
# 0     Andew   12     A
# 1    Bhuvan   18     B
# 2   Clinton   11     A
# 3     Drake   12     C
# 4     Eisha   13     B
# 5    Farhan   22     C
# 6    Garima   11     A
# 7  Himanshu   19     A
# 8    Ishaan   10     D
# 9     Jason    9     B

# %%
Json_2=pd.read_json('/content/drive/MyDrive/Colab Notebooks/DataSets/Multi_dataSet/Reading_Json/nested.json',lines=True)
Json_2
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-d16cb2a94866> in <cell line: 1>()
# ----> 1 Json_2=pd.read_json('/content/drive/MyDrive/Colab Notebooks/DataSets/Multi_dataSet/Reading_Json/nested.json',lines=True)
#       2 Json_2
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/json/_json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options, dtype_backend, engine)
#     782         return json_reader
#     783     else:
# --> 784         return json_reader.read()
#     785
#     786
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/json/_json.py in read(self)
#     971                         data = ensure_str(self.data)
#     972                         data_lines = data.split("\n")
# ...

# %%
import json
with open('/content/drive/MyDrive/Colab Notebooks/DataSets/Multi_dataSet/Reading_Json/nested.json') as f:
  my_json_3=json.load(f)

print(my_json_3)
# Out:
# [{'student_roll_no': 101, 'details': {'name': 'Andew', 'age': 12, 'grade': 'A'}}, {'student_roll_no': 102, 'details': {'name': 'Bhuvan', 'age': 18, 'grade': 'B'}}, {'student_roll_no': 103, 'details': {'name': 'Clinton', 'age': 11, 'grade': 'A'}}, {'student_roll_no': 104, 'details': {'name': 'Drake', 'age': 12, 'grade': 'C'}}, {'student_roll_no': 105, 'details': {'name': 'Eisha', 'age': 13, 'grade': 'B'}}, {'student_roll_no': 106, 'details': {'name': 'Farhan', 'age': 22, 'grade': 'C'}}, {'student_roll_no': 107, 'details': {'name': 'Garima', 'age': 11, 'grade': 'A'}}, {'student_roll_no': 108, 'details': {'name': 'Himanshu', 'age': 19, 'grade': 'A'}}, {'student_roll_no': 109, 'details': {'name': 'Ishaan', 'age': 10, 'grade': 'D'}}, {'student_roll_no': 110, 'details': {'name': 'Jason', 'age': 9, 'grade': 'B'}}]

# %%
from pprint import pprint
pprint(my_json_3)
# Out:
# [{'details': {'age': 12, 'grade': 'A', 'name': 'Andew'},
#   'student_roll_no': 101},
#  {'details': {'age': 18, 'grade': 'B', 'name': 'Bhuvan'},
#   'student_roll_no': 102},
#  {'details': {'age': 11, 'grade': 'A', 'name': 'Clinton'},
#   'student_roll_no': 103},
#  {'details': {'age': 12, 'grade': 'C', 'name': 'Drake'},
#   'student_roll_no': 104},
#  {'details': {'age': 13, 'grade': 'B', 'name': 'Eisha'},
#   'student_roll_no': 105},
#  {'details': {'age': 22, 'grade': 'C', 'name': 'Farhan'},
#   'student_roll_no': 106},
#  {'details': {'age': 11, 'grade': 'A', 'name': 'Garima'},
#   'student_roll_no': 107},
#  {'details': {'age': 19, 'grade': 'A', 'name': 'Himanshu'},
#   'student_roll_no': 108},
#  {'details': {'age': 10, 'grade': 'D', 'name': 'Ishaan'},
#   'student_roll_no': 109},
#  {'details': {'age': 9, 'grade': 'B', 'name': 'Jason'}, 'student_roll_no': 110}]
